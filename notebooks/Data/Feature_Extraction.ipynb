# %%
import os, sys
from tqdm import tqdm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import zipfile
import shutil
from pathlib import Path

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Loading packages

# %%
import sys
from pathlib import Path

here_path = Path().resolve()
repo_path = here_path.parents[1]
sys.path.append(str(repo_path))

# %%
from py.utils import verifyDir, verifyFile, verifyType

# %%
from py.config import Config

cfg = Config()

np.random.seed(cfg.RANDOM_STATE)
cfg.DATA_PATH, cfg.MODEL_PATH
# Out:
# ('/media/felipe/DATA21/datasets/', '/media/felipe/DATA21/models/')

# %%
QSCORE_PATH=f"{cfg.DATA_PATH}pp1/Qscores/"
IMAGES_PATH = f"{cfg.DATA_PATH}pp1/images/"
FEATURES_PATH = f"{cfg.MODEL_PATH}pp1/urbanvgg/{cfg.YEAR_STUDIED}/features/"

# %%
verifyDir(FEATURES_PATH)

# %% [markdown]
# ### Loading data

# %%
# %%time
data_df = pd.read_csv(f"{QSCORE_PATH}scores.csv", sep=";", low_memory=False)
data_df["image_path"] = f"{IMAGES_PATH}{cfg.YEAR_STUDIED}/" + data_df["image_path"]
data_df.sort_values(by=[cfg.PERCEPTION_METRIC], ascending=False, inplace=True)
data_df
# Out:
# CPU times: user 4 ms, sys: 2 ms, total: 5.99 ms
# Wall time: 5.67 ms
#       image_id    safety  safety_err  uniquely  uniquely_err   wealthy  \
# 1130      4340  8.350865    0.621166  4.528970      0.668607  7.245005
# 891       4196  8.327766    0.556107  5.022737      0.833578  7.498167
# 1117      4189  8.327241    0.602638  7.108436      0.738665  7.594670
# 370       3527  8.245561    0.456143  7.760654      0.836348  8.142057
# 303       4727  8.236001    0.510115  7.601103      0.631219  9.164302
# ...        ...       ...         ...       ...           ...       ...
# 375       3520  0.762055    0.460119  2.167670      0.572258  1.766562
# 301       4725  0.560845    0.582538  2.764210      0.757413  0.966390
# 2276      4904  0.517857    0.527475  2.454082      0.681900  1.576652
# 1188      4162  0.465477    0.462276  1.970528      0.661715  1.627882
# 2152      4074  0.211544    0.574673  2.742072      0.794404  1.388283
#
#       wealthy_err      lat     long      city  Heading  Pitch  \
# 1130     0.577930  42.3354 -71.1407    Boston     85.0   -3.0
# 891      0.656081  40.6780 -73.9703  New York    329.0    1.0
# 1117     0.634063  40.6948 -73.9712  New York     33.0   11.0
# 370      0.693277  40.6795 -73.9731  New York    324.0    3.0
# 303      0.627555  42.3417 -71.0792    Boston    105.0    6.0
# ...           ...      ...      ...       ...      ...    ...
# 375      0.470312  40.6307 -74.0047  New York    346.0   -1.0
# 301      0.523086  42.3812 -71.0890    Boston     15.0   -3.0
# 2276     0.381375  42.3888 -71.0872    Boston      8.0   -2.0
# 1188     0.514609  40.7096 -73.9278  New York     28.0    4.0
# 2152     0.559084  40.7035 -73.9447  New York    214.0   -4.0
#
#                                              image_path      continent country
# 1130  /media/felipe/DATA21/datasets/pp1/images/2013/...  North America     USA
# 891   /media/felipe/DATA21/datasets/pp1/images/2013/...  North America     USA
# 1117  /media/felipe/DATA21/datasets/pp1/images/2013/...  North America     USA
# 370   /media/felipe/DATA21/datasets/pp1/images/2013/...  North America     USA
# 303   /media/felipe/DATA21/datasets/pp1/images/2013/...  North America     USA
# ...                                                 ...            ...     ...
# 375   /media/felipe/DATA21/datasets/pp1/images/2013/...  North America     USA
# 301   /media/felipe/DATA21/datasets/pp1/images/2013/...  North America     USA
# 2276  /media/felipe/DATA21/datasets/pp1/images/2013/...  North America     USA
# 1188  /media/felipe/DATA21/datasets/pp1/images/2013/...  North America     USA
# 2152  /media/felipe/DATA21/datasets/pp1/images/2013/...  North America     USA
#
# [2456 rows x 15 columns]

# %% [markdown]
# ### Feature Extraction

# %%
features_dict = {"image_id": data_df["image_id"].tolist(), 
                 "image_path": data_df["image_path"].tolist(),
                 "gist": [],
                 "sift": [],
                 "fisher": [],
                }

# %% [markdown]
# #### GIST

# %%
from py.features.gist import extract_gist_features

# %%
# %%time
gist_features = []
for img_path in tqdm(features_dict["image_path"]):
    desc = extract_gist_features(img_path)
    if desc is not None:
        gist_features.append(desc)
    else:
        gist_features.append(None)
        print(f"Not Extracted {len(desc)} descriptors from {img_path}")
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2456/2456 [04:22<00:00,  9.36it/s]
# CPU times: user 4min 22s, sys: 431 ms, total: 4min 22s
# Wall time: 4min 22s

# %%
features_dict["gist"] = np.array(gist_features).tolist()

# %%
print(f"GIST shape: {gist_features[0].shape}")
print(f"GIST norm: {np.linalg.norm(gist_features):.4f}")
# Out:
# GIST shape: (256,)
# GIST norm: 0.7388

# %% [markdown]
# #### SIFT

# %%
from py.features.sift import extract_sift_descriptors

# %%
# %%time
sift_descriptors = []
for img_path in tqdm(features_dict["image_path"]):
    desc = extract_sift_descriptors(img_path)
    if desc is not None:
        sift_descriptors.append(desc)
        #print(f"Extracted {len(desc)} descriptors from {img_path}")
    else:
        sift_descriptors.append(None)
        print(f"Not Extracted {len(desc)} descriptors from {img_path}")
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2456/2456 [00:40<00:00, 60.71it/s]
# CPU times: user 3min 26s, sys: 35.6 s, total: 4min 2s
# Wall time: 40.5 s

# %%
features_dict["sift"] = sift_descriptors

# %%
print(f"SIFT shape: {sift_descriptors[0].shape}")
# Out:
# SIFT shape: (3279, 128)

# %%
shapes = [a.shape for a in sift_descriptors]
unique_shapes = sorted(set(shapes))
print("Num arrays:", len(sift_descriptors))
print("Unique shapes:", unique_shapes[:20], "..." if len(unique_shapes) > 20 else "")
print("How many unique shapes:", len(unique_shapes))
# Out:
# Num arrays: 2456
# Unique shapes: [(23, 128), (261, 128), (358, 128), (519, 128), (521, 128), (609, 128), (639, 128), (644, 128), (659, 128), (702, 128), (741, 128), (745, 128), (762, 128), (784, 128), (789, 128), (798, 128), (801, 128), (805, 128), (818, 128), (826, 128)] ...
# How many unique shapes: 1175

# %% [markdown]
# ### Fisher

# %%
from py.features.fisher import FisherVectorEncoder

# %%
# %%time
fv_encoder = FisherVectorEncoder(n_components=32)
fv_encoder.fit(features_dict["sift"])
print(f"Trained GMM with {fv_encoder.n_components} components")
# Out:
# Trained GMM with 32 components
# CPU times: user 3h 10min 9s, sys: 3min 8s, total: 3h 13min 18s
# Wall time: 18min 41s

# %%
# %%time
fisher_vectors = []
for descriptor in tqdm(features_dict["sift"]):
    try:
        fisher_vec = fv_encoder.encode(descriptor)
        fisher_vectors.append(fisher_vec)
    except Exception as e:
        fisher_vectors.append(None)
        print(f"Error {e} extracting ...")
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2456/2456 [00:45<00:00, 54.22it/s]
# CPU times: user 17min 32s, sys: 516 ms, total: 17min 32s
# Wall time: 45.3 s

# %%
features_dict["fisher"] = np.array(fisher_vectors).tolist()

# %%
print(f"Fisher Vector shape: {len(fisher_vectors[0])}")
print(f"Fisher Vector norm: {np.linalg.norm(fisher_vectors):.4f}")
# Out:
# Fisher Vector shape: 8192
# Fisher Vector norm: 49.5580

# %% [markdown]
# ### Saving features

# %%
# %%time
import pickle

with open(f"{FEATURES_PATH}features.pkl", "wb") as f:
    pickle.dump(features_dict, f)
# Out:
# CPU times: user 2.16 s, sys: 955 ms, total: 3.11 s
# Wall time: 1.35 s
